# %%
import pandas as pd
import numpy as np
from scipy import stats
from datetime import datetime
timestamp = datetime.now().strftime('%Y%m%d')
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
df_final = pd.read_csv("/Users/ayo/Desktop/_GSAIS_/Research/OralHealth_tokyo/paper_analysis/data/data_OnlyAbuse_N1235.csv", index_col=0)
df_final
# Out:
#       No_All       CGC        date     sex  age_year  age_month        age  \
# 2          3     tokyo  2016-10-12  Female        15          1  15.083333
# 3          4     tokyo  2016-10-12  Female        14          5  14.416667
# 4          5     tokyo  2016-10-12  Female        15         10  15.833333
# 7          8     tokyo  2016-10-12  Female        15          0  15.000000
# 8          9     tokyo  2016-10-12  Female        17          0  17.000000
# ...      ...       ...         ...     ...       ...        ...        ...
# 2149    2468  itabashi  2023-02-02    Male        15          0  15.000000
# 2152    2471  itabashi  2023-02-02  Female        16          9  16.750000
# 2156    2475  itabashi  2023-03-02    Male        17          8  17.666667
# 2157    2476  itabashi  2023-03-02  Female        17          0  17.000000
# 2161    2480  itabashi  2023-03-02  Female        17          0  17.000000
#
#       abuse_1            abuse  abuse_num  ...  Present_Teeth  \
# ...
